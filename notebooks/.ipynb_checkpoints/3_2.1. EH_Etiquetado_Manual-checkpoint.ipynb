# %%
import pandas as pd
import re
from sklearn.ensemble import IsolationForest  # Para detección de anomalías
import dash
from dash import dcc, html
import plotly.express as px  # Para visualización
from datetime import datetime, timedelta

# %%
dir_path = "../process/"
file= "external_test_data"# "train_data" #
#logs_df = pd.read_csv(f"{dir_path}external_test_data.csv", encoding='utf-8')
logs_df = pd.read_csv(f"{dir_path}{file}.csv", encoding='utf-8')

print(set(logs_df["Level"]))
print(logs_df.shape)
logs_df.head()
# Out:
# {'Error', 'Informativo', 'Advertencia'}
# (1855, 6)
#                                              Content        Level  \
# 0  setSystemUiVisibility vis=0 mask=1 oldVal=4000...  Informativo
# 1  cleanUpApplicationRecordLocked, pid: 12236, re...  Informativo
# 2                       state.clipTopAmount:103, i:0  Informativo
# 3  ready=true,policy=3,wakefulness=1,wksummary=0x...  Informativo
# 4  ready=true,policy=3,wakefulness=1,wksummary=0x...  Informativo
#
#                   datetime  content_length   source  \
# 0  2024-03-17 16:15:51.792              12  Android
# 1  2024-03-17 16:15:19.993               4  Android
# 2  2024-03-17 16:13:46.306               2  Android
# 3  2024-03-17 16:15:07.847              17  Android
# 4  2024-03-17 16:15:06.000              17  Android
#
#                                        Clean_Content
# 0  setsystemuivisibility vis mask oldval newval d...
# 1   cleanupapplicationrecordlocked pid restart false
# 2                                state cliptopamount
# 3  ready true policy wakefulness wksummary uasumm...
# 4  ready true policy wakefulness wksummary uasumm...

# %%
def get_severity(content):
    content_lower = content.lower()
    
    if any(x in content_lower for x in ['unreachable', 'workerenv error', 'goodbye', 'error contacting', 'forbidden',  'fatal', 'crash', 'unknown', 'empty', 'timeout', 'not responding', 'unexpected', 'error state']):
        return 'Crítico'
    elif any(x in content_lower for x in ['screen', 'broadcast', 'started', 'running', 'status', 'activated', 'cannot']):
        return 'Información'
    elif any(x in content_lower for x in [ 'dump','resume', 'connected', 'connection', 'ready', 'info', 'init', 'connect', 'message', 'connection', 'null', 'policy', 'ok', 'broken', 'terminating']):
        return 'Depuración'
    elif any(x in content_lower for x in ['denied', 'error state', 'overheat', 'failed', 'error', 'high', 'warn', 'alert', 'detected', 'exception',  'interrupted', 'interrupting', 'leaving', 'dropped', 'limiting', 'unable']):
        return 'Advertencia'
    else:
        return 'No relevante'

# %%
def get_origin(content):
    content_lower = content.lower()
    if any(x in content_lower for x in ['boot', 'resume', 'start', 'stop', 'reboot', 'sleep', 'wake', 'standby', 'hibernat']):
        return 'Aplicación'
    if any(x in content_lower for x in ['keepalive', 'info', 'slow', 'init', 'memory', 'battery', 'gc', 'block', 'fatal', 'denied', 'abort', 'load', 'leaving thread', 'usage', 'status', 'temperature']):
        return 'Sistema operativo'
    if any(x in content_lower for x in ['shutdown sock', 'renew', 'start service', 'waiting', 'interrupting', 'interrupted', 'caught end', 'sleep', 'wake', 'standby', 'hibernat']):
        return 'Gestión de energía'
    if any(x in content_lower for x in ['connect', 'disconnect', 'detected', 'found', 'input', 'hover', 'change', 'submit', 'clicked', 'button', 'scroll']):
        return 'Conectividad'
    if any(x in content_lower for x in ['exception', 'fail', 'error', 'retry', 'illegal', 'forbidden', 'unexpected', 'null', 'unknown', 'crashed service', 'interrupted', 'interrupting', 'goodbye']):
        return 'Sistema de archivos'


    return 'Otro'

# %%
def get_event_type(content):
    content = content.lower()
    if any(x in content for x in ['down', 'shutdown', 'halt', 'terminate', 'terminated', 'terminating', 'killed', 'stopped', 'stop', 'exit', 'exited', 'aborted' ]):
        return 'Parada de procesos'
    elif any(x in content for x in ['scroll', 'start service', 'limiting', 'button', 'waiting', 'clicked', 'renew', 'connect', 'disconnect', 'detected', 'input', 'hover', 'change', 'submit', 'found']):
        return 'Eventos'
    elif any(x in content for x in ['exception', 'goodbye', 'fail', 'error', 'retry', 'crashed', 'illegal', 'forbidden', 'unexpected', 'null', 'unknown', 'crashed service', 'interrupted', 'interrupting' ]):
        return 'Errores'
    elif any(x in content for x in ['boot',  'resume', 'start', 'stop', 'reboot', 'sleep', 'wake', 'standby','hibernat']):
        return 'Transicion'
    elif any(x in content for x in ['keepalive','info', 'slow', 'init', 'memory', 'battery', 'gc', 'block', 'fatal', 'denied', 'abort', 'load', 'leaving thread', 'usage', 'status', 'temperature']):
        return 'Monitoreo'

    else:
        return 'Otro'

# %%
# Aplicar etiquetas
logs_df['Severidad'] = logs_df['Content'].apply(get_severity)
logs_df['Origen'] = logs_df['Content'].apply(get_origin)
logs_df['TipoEvento'] = logs_df['Content'].apply(get_event_type)

# %%
logs_df['datetime'] = pd.to_datetime(logs_df['datetime'], errors='coerce')
logs_df[logs_df["source"]=="Apache"].head()
# Out:
#                                                Content        Level  \
# 497   jk2_init() Found child 1951 in scoreboard slot 7  Informativo
# 498            mod_jk child workerEnv in error state 6        Error
# 499   jk2_init() Found child 2001 in scoreboard slot 9  Informativo
# 500  jk2_init() Found child 1568 in scoreboard slot 13  Informativo
# 501   jk2_init() Found child 5049 in scoreboard slot 7  Informativo
#
#                datetime  content_length  source                Clean_Content  \
# 497 2005-12-04 20:24:45               3  Apache        child scoreboard slot
# 498 2005-12-04 17:43:12               4  Apache  child workerenv error state
# 499 2005-12-04 20:33:35               3  Apache        child scoreboard slot
# 500 2005-12-04 17:43:08               3  Apache        child scoreboard slot
# 501 2005-12-05 07:57:01               3  Apache        child scoreboard slot
#
#       Severidad      Origen TipoEvento
# 497  Depuración        Otro    Eventos
# 498     Crítico  Aplicación    Errores
# 499  Depuración        Otro    Eventos
# 500  Depuración        Otro    Eventos
# 501  Depuración        Otro    Eventos

# %%
import pandas as pd
from datetime import timedelta

# Asegura que 'datetime' sea tipo datetime
logs_df['datetime'] = pd.to_datetime(logs_df['datetime'], errors='coerce')

# Ordenar el DataFrame completo por datetime
logs_df = logs_df.sort_values(by='datetime')

# Nueva columna para las etiquetas de frecuencia
logs_df['Frecuencia'] = 'Sin etiquetar'

# Agrupar por 'Source' y 'Content' para evaluar eventos con contextos temporales distintos
grouped = logs_df.groupby(['source', 'Content'])

for (source, content), group in grouped:
    group = group.sort_values(by='datetime')
    count = len(group)

    if count == 1:
        freq_label = 'Único'
    else:
        time_deltas = group['datetime'].diff().dropna()
        avg_delta = time_deltas.mean()

        if avg_delta < timedelta(minutes=1) and count > 3:
            freq_label = 'Recurrente anómalo'
        elif timedelta(minutes=1) <= avg_delta <= timedelta(minutes=30) and time_deltas.std() < timedelta(seconds=5):
            freq_label = 'Recurrente esperado'
        elif any(x in content.lower() for x in ['doze mode active', 'no internet access for 10 min', 'bluetooth on']):
            freq_label = 'Continuo'
        else:
            freq_label = 'Recurrente esperado'

    logs_df.loc[group.index, 'Frecuencia'] = freq_label

# %%
# Verificar el resultado
print(logs_df[['Content', 'Frecuencia']].drop_duplicates())
# Out:
#                                                Content           Frecuencia
# 683  workerEnv.init() ok /etc/httpd/conf/workers2.p...  Recurrente esperado
# 649            mod_jk child workerEnv in error state 6  Recurrente esperado
# 632   jk2_init() Found child 6740 in scoreboard slot 7  Recurrente esperado
# 528  jk2_init() Found child 6744 in scoreboard slot 10                Único
# 624   jk2_init() Found child 6750 in scoreboard slot 7                Único
# ..                                                 ...                  ...
# 211       makeExpandedInvisible: mExpandedVisible=true                Único
# 177  overlapAmount:220.0, previousNotificationEnd:0...                Único
# 260  updateClipping isOverlap:true, getTopPadding=3...                Único
# 449      makeExpandedInvisible: mExpandedVisible=false                Único
# 358                         onNotificationClick called                Único
#
# [794 rows x 2 columns]

# %%
from sklearn.ensemble import IsolationForest

# Feature engineering básico
logs_df['ContentLength'] = logs_df['Content'].apply(len)
logs_df['Hour'] = pd.to_datetime(logs_df['datetime'], format='%H:%M:%S.%f').dt.hour

# Variables numéricas para análisis
X = logs_df[['ContentLength', 'Hour']]
model = IsolationForest(contamination=0.05, random_state=42)
logs_df['Anomaly'] = model.fit_predict(X)
logs_df.head()
# Out:
#                                                Content        Level  \
# 683  workerEnv.init() ok /etc/httpd/conf/workers2.p...  Informativo
# 649            mod_jk child workerEnv in error state 6        Error
# 516  workerEnv.init() ok /etc/httpd/conf/workers2.p...  Informativo
# 632   jk2_init() Found child 6740 in scoreboard slot 7  Informativo
# 528  jk2_init() Found child 6744 in scoreboard slot 10  Informativo
#
#                datetime  content_length  source  \
# 683 2005-12-04 04:51:14               6  Apache
# 649 2005-12-04 04:51:18               4  Apache
# 516 2005-12-04 04:51:52               6  Apache
# 632 2005-12-04 04:52:05               3  Apache
# 528 2005-12-04 04:52:36               3  Apache
#
#                                Clean_Content   Severidad      Origen  \
# 683  workerenv init ok httpd conf properties  Depuración        Otro
# 649              child workerenv error state     Crítico  Aplicación
# 516  workerenv init ok httpd conf properties  Depuración        Otro
# 632                    child scoreboard slot  Depuración        Otro
# 528                    child scoreboard slot  Depuración        Otro
#
#     TipoEvento           Frecuencia  ContentLength  Hour  Anomaly
# 683  Monitoreo  Recurrente esperado             55     4       -1
# 649    Errores  Recurrente esperado             39     4       -1
# 516  Monitoreo  Recurrente esperado             55     4       -1
# 632    Eventos  Recurrente esperado             48     4        1
# 528    Eventos                Único             49     4        1

# %%
logs_df.to_csv(f"{dir_path}3_21{file}_heuristic_tagging.csv", index=False, encoding='utf-8')

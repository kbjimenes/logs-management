# %%
import pandas as pd
import numpy as np
import re

# %%
dir_path = "results/"

# %% [markdown]
# ## Entrenamiento folds

# %%
file=  "resuls_train_fold_heuristics" #"train_data" 
res_df = pd.read_csv(f"{dir_path}{file}.csv", encoding='utf-8')
res_df.head(7)
# Out:
#           group  precision    recall  f1-score      support  fold technique
# 0   Advertencia   0.781457  0.655556  0.712991   720.000000     0        RH
# 1         Error   0.792056  0.470833  0.590592   720.000000     0        RH
# 2   Informativo   0.583333  0.913889  0.712121   720.000000     0        RH
# 3      accuracy   0.680093  0.680093  0.680093     0.680093     0        RH
# 4     macro-avg   0.718949  0.680093  0.671901  2160.000000     0        RH
# 5  weighted-avg   0.718949  0.680093  0.671901  2160.000000     0        RH
# 6   Advertencia   0.782534  0.635605  0.701458   719.000000     1        RH

# %%
res_df_global=res_df[res_df["group"]=='macro-avg']
res_df_global.head()
# Out:
#         group  precision    recall  f1-score  support  fold technique
# 4   macro-avg   0.718949  0.680093  0.671901   2160.0     0        RH
# 10  macro-avg   0.727505  0.676402  0.668959   2157.0     1        RH
# 16  macro-avg   0.796719  0.717200  0.713109   2157.0     2        RH
# 22  macro-avg   0.710661  0.668521  0.659997   2157.0     3        RH
# 28  macro-avg   0.709707  0.670376  0.662956   2157.0     4        RH

# %%
print("precision", np.mean(res_df_global["precision"]), "with std ", np.std(res_df_global["precision"]))
print("recall", np.mean(res_df_global["recall"]), "with std ", np.std(res_df_global["recall"]))
print("f1-score", np.mean(res_df_global["f1-score"]), "with std ", np.std(res_df_global["f1-score"]))
# Out:
# precision 0.7476328999999999 with std  0.03858107661911472
# recall 0.6899379 with std  0.020900897183853132
# f1-score 0.6835386000000001 with std  0.022633998132013736

# %%
res_df_global=res_df[res_df["group"]=='Advertencia']
print("precision", np.mean(res_df_global["precision"]), "with std ", np.std(res_df_global["precision"]))
print("recall", np.mean(res_df_global["recall"]), "with std ", np.std(res_df_global["recall"]))
print("f1-score", np.mean(res_df_global["f1-score"]), "with std ", np.std(res_df_global["f1-score"]))
# Out:
# precision 0.7906743999999999 with std  0.015802973670800073
# recall 0.678073 with std  0.05875330075493631
# f1-score 0.7292483 with std  0.04041146115410824

# %%
res_df_global=res_df[res_df["group"]=='Error']
print("precision", np.mean(res_df_global["precision"]), "with std ", np.std(res_df_global["precision"]))
print("recall", np.mean(res_df_global["recall"]), "with std ", np.std(res_df_global["recall"]))
print("f1-score", np.mean(res_df_global["f1-score"]), "with std ", np.std(res_df_global["f1-score"]))
# Out:
# precision 0.8779184000000001 with std  0.09988583913868873
# recall 0.47559510000000005 with std  0.005440750085236403
# f1-score 0.6153601 with std  0.027033493357130144

# %%
res_df_global=res_df[res_df["group"]=='Informativo']
print("precision", np.mean(res_df_global["precision"]), "with std ", np.std(res_df_global["precision"]))
print("recall", np.mean(res_df_global["recall"]), "with std ", np.std(res_df_global["recall"]))
print("f1-score", np.mean(res_df_global["f1-score"]), "with std ", np.std(res_df_global["f1-score"]))
# Out:
# precision 0.5743056999999999 with std  0.004612286115366221
# recall 0.9161455000000001 with std  0.00497241603750128
# f1-score 0.7060074000000001 with std  0.003647540354814481

# %% [markdown]
# ## Val folds

# %%
file=  "resuls_val_fold_heuristics" #"train_data" 
res_df = pd.read_csv(f"{dir_path}{file}.csv", encoding='utf-8')
res_df.head(7)
# Out:
#           group  precision    recall  f1-score    support  fold technique
# 0   Advertencia   0.750000  0.455696  0.566929   79.00000     0        RH
# 1         Error   0.976190  0.518987  0.677686   79.00000     0        RH
# 2   Informativo   0.517007  0.962025  0.672566   79.00000     0        RH
# 3      accuracy   0.645570  0.645570  0.645570    0.64557     0        RH
# 4     macro-avg   0.747732  0.645570  0.639060  237.00000     0        RH
# 5  weighted-avg   0.747732  0.645570  0.639060  237.00000     0        RH
# 6   Advertencia   0.714286  0.625000  0.666667   80.00000     1        RH

# %%
res_df_global=res_df[res_df["group"]=='macro-avg']
res_df_global.head()
# Out:
#         group  precision    recall  f1-score  support  fold technique
# 4   macro-avg   0.747732  0.645570  0.639060    237.0     0        RH
# 10  macro-avg   0.767811  0.695833  0.690542    240.0     1        RH
# 16  macro-avg   0.741158  0.620833  0.607389    240.0     2        RH
# 22  macro-avg   0.687173  0.595833  0.601968    240.0     3        RH
# 28  macro-avg   0.697037  0.587500  0.579771    240.0     4        RH

# %%
print("precision", np.mean(res_df_global["precision"]), "with std ", np.std(res_df_global["precision"]))
print("recall", np.mean(res_df_global["recall"]), "with std ", np.std(res_df_global["recall"]))
print("f1-score", np.mean(res_df_global["f1-score"]), "with std ", np.std(res_df_global["f1-score"]))
# Out:
# precision 0.7386725000000001 with std  0.02564968499319241
# recall 0.6337235 with std  0.03201933416000403
# f1-score 0.6271051000000001 with std  0.032394648500794064

# %%
res_df_global=res_df[res_df["group"]=='Advertencia']
res_df_global.head()
# Out:
#           group  precision    recall  f1-score  support  fold technique
# 0   Advertencia   0.750000  0.455696  0.566929     79.0     0        RH
# 6   Advertencia   0.714286  0.625000  0.666667     80.0     1        RH
# 12  Advertencia   0.716981  0.475000  0.571429     80.0     2        RH
# 18  Advertencia   0.588235  0.500000  0.540541     80.0     3        RH
# 24  Advertencia   0.611111  0.412500  0.492537     80.0     4        RH

# %%
print("precision", np.mean(res_df_global["precision"]), "with std ", np.std(res_df_global["precision"]))
print("recall", np.mean(res_df_global["recall"]), "with std ", np.std(res_df_global["recall"]))
print("f1-score", np.mean(res_df_global["f1-score"]), "with std ", np.std(res_df_global["f1-score"]))
# Out:
# precision 0.7045896 with std  0.05795896821407367
# recall 0.4918196 with std  0.06190711184863982
# f1-score 0.5765667 with std  0.04899455586705527

# %%
res_df_global=res_df[res_df["group"]=='Error']
res_df_global.head()
# Out:
#     group  precision    recall  f1-score  support  fold technique
# 1   Error    0.97619  0.518987  0.677686     79.0     0        RH
# 7   Error    1.00000  0.512500  0.677686     80.0     1        RH
# 13  Error    1.00000  0.412500  0.584071     80.0     2        RH
# 19  Error    1.00000  0.512500  0.677686     80.0     3        RH
# 25  Error    1.00000  0.450000  0.620690     80.0     4        RH

# %%
print("precision", np.mean(res_df_global["precision"]), "with std ", np.std(res_df_global["precision"]))
print("recall", np.mean(res_df_global["recall"]), "with std ", np.std(res_df_global["recall"]))
print("f1-score", np.mean(res_df_global["f1-score"]), "with std ", np.std(res_df_global["f1-score"]))
# Out:
# precision 0.9976189999999999 with std  0.007142999999999999
# recall 0.4756487 with std  0.04895089177134569
# f1-score 0.6425997 with std  0.044748146341608404

# %%
res_df_global=res_df[res_df["group"]=='Informativo']
res_df_global.head()
# Out:
#           group  precision    recall  f1-score  support  fold technique
# 2   Informativo   0.517007  0.962025  0.672566     79.0     0        RH
# 8   Informativo   0.589147  0.950000  0.727273     80.0     1        RH
# 14  Informativo   0.506494  0.975000  0.666667     80.0     2        RH
# 20  Informativo   0.473282  0.775000  0.587678     80.0     3        RH
# 26  Informativo   0.480000  0.900000  0.626087     80.0     4        RH

# %%
print("precision", np.mean(res_df_global["precision"]), "with std ", np.std(res_df_global["precision"]))
print("recall", np.mean(res_df_global["recall"]), "with std ", np.std(res_df_global["recall"]))
print("f1-score", np.mean(res_df_global["f1-score"]), "with std ", np.std(res_df_global["f1-score"]))
# Out:
# precision 0.5138088999999999 with std  0.032810335629036166
# recall 0.9337024999999999 with std  0.05888634439536893
# f1-score 0.6621493999999999 with std  0.036157560003960434
